# %% [markdown]
# Day 14 (Check Julius AI)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
import random
import plotly.express as px
from sklearn import datasets
print("Libraries imported")
# Out:
# Libraries imported

# %%
#data sets inder seaborn library
print(sns.get_dataset_names())
print(len(sns.get_dataset_names()))
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# 22

# %%
df_titanic=sns.load_dataset('titanic')
df_titanic.sample(2)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 111         0       3  female  14.5      1      0  14.4542        C  Third
# 820         1       1  female  52.0      1      1  93.5000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 111  child       False  NaN    Cherbourg    no  False
# 820  woman       False    B  Southampton   yes  False

# %%
# sns.countplot
# sns.barplot
# sns.boxplot
# sns.scatterplot
# sns.catplot
# sns.kdeplot

# %%
#To count the values for one column based on another column
warnings.filterwarnings('ignore')
sns.countplot(data=df_titanic, x='sex', hue='alive', palette=sns.color_palette("viridis")) #hue: divide further based on categorical data
plt.title("Titanic survival based on Gender")
plt.show() #This code show us the anotamy, it will provide the lable by it's own

# %%
sns.barplot(data=df_titanic, x='class', y='fare', hue='alive', palette=sns.color_palette('ocean',2)) #use estimator='mean' to change confidence interval
plt.show
#The bar is a confidence interval (fluctuation) showing the fare price average fluctuation 
#CI default value is 95%
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#To remove confidence interval use: use errorbar=('ci',0), ci value will be 0 (not calling any confidence interval)
sns.barplot(data=df_titanic, x='class', y='fare', hue='alive',errorbar=('ci',0), palette=sns.color_palette('ocean',2)) #use estimator='mean' to change confidence interval
plt.grid(color='b',alpha=0.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sns.boxplot() to check outliers
sns.boxplot(data=df_titanic, x='class', y='fare', hue='sex')
plt.show()

# %%
#sns.boxplot() to check skewness in outlirs
plt.figure(figsize=(10,5))
sns.boxplot(data=df_titanic, y='class', x='fare', hue='sex', orient='h')
plt.show()

# %%
# sns.violinplot
plt.figure(figsize=(10,5))
sns.violinplot(data=df_titanic, x='class', y='fare', hue='sex', orient='v')
plt.show()

# %%
df_pen=sns.load_dataset('penguins')
df_pen.sample(2)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 110     Adelie  Biscoe            38.1           16.5              198.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
#
#      body_mass_g     sex
# 110       3825.0  Female
# 167       4050.0    Male

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df_pen, x='species', y='body_mass_g', hue='sex')
plt.show()

# %%
sns.scatterplot(data=df_pen, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=df_pen, x='bill_length_mm', y='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.regplot(data=df_pen, x='bill_length_mm', y='bill_depth_mm')
plt.show()

# %%
df_tips=sns.load_dataset('tips')
df_tips.sample(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
# sns.catplot(data=df_tips, x='total_bill', y='tip')
sns.catplot(data=df_tips, y='total_bill', x='time', kind='bar')
# plt.xticks(0,100)

# %%
sns.catplot(data=df_tips, y='total_bill', x='time', kind='bar', hue='sex', row='smoker',col='day')

# %%
sns.catplot(data=df_tips, y='total_bill', x='time', kind='violin', hue='sex', row='smoker',col='day')

# %%
# to plot scatter plot
sns.lmplot(data=df_tips, y='tip', x='total_bill')

# %%
# to plot scatter plot
sns.lmplot(data=df_tips, y='tip',hue='sex', x='total_bill', row='smoker', col='day')

# %%
sns.relplot(data=df_tips, x='total_bill', y='tip',hue='sex', kind='scatter',row='smoker', col='day')

# %%
df_flight=sns.load_dataset('flights')
df_flight.sample(2)
# Out:
#     year month  passengers
# 85  1956   Feb         277
# 83  1955   Dec         278

# %%
#Lineplot
sns.lineplot(data=df_flight, x='year', y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
#Lineplot
sns.lineplot(data=df_flight, x='year', y='passengers', hue='month', linestyle=('--'))
plt.grid()

# %%
df_iris=sns.load_dataset('iris')
display(df_iris.sample(2))
#Can't take string, only numbers. so we'll remove the 'species' column
df_iris2=df_iris.iloc[:,:-1]
display(df_iris2.sample(2))
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 57           4.9          2.4           3.3          1.0  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
#     sepal_length  sepal_width  petal_length  petal_width
# 91           6.1          3.0           4.6          1.4
# 37           4.9          3.6           1.4          0.1

# %%
# sns.pairplot check the relation between pairs (numeric pair vs numeric pair)
df_iris2.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# Here we can see that when sepal length increase the sepal width decreases. there is a negative correlation

# %% [markdown]
# And when petal length increase the petal width increase (more than zero). there is a positive correlation

# %%
sns.pairplot(data=df_iris2)
plt.show()

# %%
sns.pairplot(data=df_iris, hue='species',corner=True)
plt.show()
